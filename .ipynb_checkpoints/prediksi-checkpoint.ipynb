# %%
from modulku import praproses as pps, StemNstopW as stm
from joblib import load
from replace import normalisasi as nrm
import pandas as pd

# %%
#load Model yang sudah dibuat
tfidf = load('model/tfidf.w')
mnb = load('model/mnb.m')

# %%
sms = "Isi saldo TCASHmu  melalui jaringan ATM Bersama & ATM BCA! Lakukan transfer antar bank, Pilih bank TCASH (Kode bank 911). Gunakan No HP sbg no rekening tujuan."

# %%
#praproses
def praproses(sms):
    sms = pps.preprocessing(sms)
    sms = nrm.normalisasi(sms)
    sms = stm.stemmer_kata(sms)
    # sms = stm.stop_word(sms)
    return sms

# %%
data = pd.read_excel("../sms baru/new_sms.xlsx")
sms_list = data.sms.tolist()
data.head()
# Out:
#    Unnamed: 0                                                sms
# 0           0  NOMOR !!! Anda Dapat Hadiah Cek Rp.100jt Dari ...
# 1           1  RAMADHAN Sale. Disc sd 70% utk produk Reguler ...
# 2           2  Selamat! Anda mendapatkan 2 poin dari isi ulan...
# 3           3  Selamat, anda berhak mendapatkan kuota interne...
# 4           4  Big S4LE!!! Bul4n suci FAJAR 0Lshop,Dptk4n IPH...

# %%
#prediksi
prediksi = list()
for sms in sms_list:
    sms = praproses(sms)
    w = tfidf.transform([sms])
    hasil = mnb.predict(w)[0]
    prediksi.append(hasil)

# %%
dict_ = {
    'sms':sms_list,
    "prediksi":prediksi
}
df = pd.DataFrame.from_dict(dict_)
df
# Out:
#                                                    sms prediksi
# 0    NOMOR !!! Anda Dapat Hadiah Cek Rp.100jt Dari ...    fraud
# 1    RAMADHAN Sale. Disc sd 70% utk produk Reguler ...    promo
# 2    Selamat! Anda mendapatkan 2 poin dari isi ulan...    promo
# 3    Selamat, anda berhak mendapatkan kuota interne...    promo
# 4    Big S4LE!!! Bul4n suci FAJAR 0Lshop,Dptk4n IPH...    fraud
# 5    Nomor AS anda : 6285328899938 layanan ini dike...    promo
# 6    Buruan datang harga murah di SUPERDEAL BJ Home...    promo
# 7    INGIN BEBAS DARI -Dililit hutang -Biaya sekola...    fraud
# 8    KOIN ID PP : DRS047415 ID PETUGAS : 0853288999...    fraud
# 9    Selamat Paket Combo 15 GB, 300 Menit Tsel, 400...    promo
# 10   Raih JUTAAN Rupiah di bit.ly/8080Sport . denga...    promo
# 11   Selamat, Flash 390MB(7hari) Rp20000 brlaku s/d...    promo
# 12   INFO !!! RESMI Kpd Masyarakat Indonesia Anda T...    fraud
# 13                    Nomor handphone tidak terdaftar.    promo
# 14   Selamat! Anda mendapatkan 4 poin dari isi ulan...    promo
# 15   Kejutan BANK INDONESIA Poin transaksi anda akh...    fraud
# 16   center wathsapp kurang stabill gunakan center ...    fraud
# 17   Saya ganti judul mas sekarang penelitian saya ...    fraud
# 18   Plggn Yth Slmat Anda Terplh Sebagai Pemenang K...    fraud
# 19   bit.ly/baba303 Main di BABA303 Kalah atau Mena...    promo
# 20   Ass..Kami KSP NASARI Menawarkan Pinjaman ONLIN...    fraud
# 21   INFO RESMI Nomor KUOTA Anda Terpilih Sebagai p...    fraud
# 22   Yth IRHAB LUFIAS, 2 hari lagi status anda seba...    promo
# 23   Surat Pemberitahuan LAZADA. Selamat Anda Mendp...    fraud
# 24   Dapatkan 2 Burger pilihan Hanya 20rb (Beef bur...    promo
# 25   Nomor Simpati anda : 6281213448683 layanan ini...    fraud
# 26   Pelanggan yth, Paket Internet 4 GB akan berakh...    promo
# 27   TINGGAL 2 HARI LAGI! CASHBACK 25.000 utk bayar...    promo
# 28   Selamat! Anda mendapatkan 1 poin dari isi ulan...    promo
# 29   Paket 390MB utk (7 hari) Anda akan berakhir pd...    promo
# ..                                                 ...      ...
# 260  CASHBACK 25.000 di Gogobli.com bayar pake Link...    promo
# 261  Pesan terahir dri LAZAD4 Anda M-dptkan RP;175J...    fraud
# 262  Paket Best Deal Internet 10GB Rp 73000 telah a...    promo
# 263  Anda tlh melakukan transaksi M-BANKING BRI& md...    fraud
# 264  INFO !! RESMI PENGUNDIAN LAZADA 2019! "BERKAH ...    fraud
# 265  Selamat, Paket 2 GB, 2 GB VideoMax /30 hari Rp...    promo
# 266  Token PLN: 2104-2597-7999-1188-5374/SONNY-KHOE...    fraud
# 267  Pengingat: Pesanan 245293226020593 akan berakh...    fraud
# 268  [Telkomsel M-Banking] Maaf transaksi gagal, ka...    promo
# 269  Batman, Superman dan Superheroes lainnya terse...    promo
# 270  Dapatkan Rp100rb saldo+10free game(total senil...    promo
# 271  Batman, Superman dan Superheroes tersedia di H...    promo
# 272  Paket Internet 6.5 GB Rp 58000 telah aktif, be...    promo
# 273  Anda menerima SMS dari +6285241945777. SMS aka...    promo
# 274  Beli 6 Gratis 6 Donut dari DUNKIN DONUTS Kaliu...    promo
# 275  Selamat! Anda mendapatkan 5 poin dari isi ulan...    promo
# 276  BELI 1 GRATIS 1 MINUMAN - HANYA HARI INI. GRAN...    promo
# 277  Dapatkan Penawaran Pinjaman Online Tanpa Anggu...    fraud
# 278  Saksikan pertandingan liga terbaik eropa, taya...    promo
# 279  Selamat, anda berhak mendapatkan kuota interne...    promo
# 280  Gunakan kode 5759 untuk registrasi akun DANA. ...    promo
# 281                                      oo ya makasih   normal
# 282  SURAT KEPUTUSAN Shopee. Selamat anda M-dapatka...    fraud
# 283  Trm ksh tlh bertransaksi Mbanking. Anda mndptk...    promo
# 284  Belum bayar BPJS? Kesehatan km penting loh. Ad...    promo
# 285  Bayar BPJS CASHBACK 25.000 CUMA di LinkAja. Ay...    promo
# 286  KAMI DARI KSP INDOFINANCIAL Mengajukan pinjama...    fraud
# 287  Dapatkan 2 Triple Cheese Rasher + 2Kentang + 2...    promo
# 288  Nikmati Lezatnya Burger Tripple Cheese Blackpa...    promo
# 289  Selamat, Paket Internet 3GB /30 hari Rp 32000 ...    promo
#
# [290 rows x 2 columns]

# %%
df.to_excel("hasil prediksi/hasil_prediksi.xlsx")
